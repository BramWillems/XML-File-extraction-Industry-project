# %%
import zipfile
import xml.etree.ElementTree as ET

# --- CONFIG ---
file1 = "Zoekwoordenonderzoek.docx"
file2 = "Zoekwoordenonderzoek2.docx"

def get_styles(docx_file):
    styles = []
    with zipfile.ZipFile(docx_file) as docx:
        xml_content = docx.read("word/document.xml")
        tree = ET.fromstring(xml_content)
        # Word XML uses namespaces
        ns = {"w": "http://schemas.openxmlformats.org/wordprocessingml/2006/main"}

        for r in tree.findall(".//w:r", ns):
            text = "".join([t.text for t in r.findall("w:t", ns) if t.text])
            if not text.strip():
                continue
            rpr = r.find("w:rPr", ns)
            font, size = None, None
            if rpr is not None:
                rfonts = rpr.find("w:rFonts", ns)
                if rfonts is not None:
                    font = rfonts.attrib.get("{http://schemas.openxmlformats.org/wordprocessingml/2006/main}ascii")
                rsize = rpr.find("w:sz", ns)
                if rsize is not None:
                    size = rsize.attrib.get("{http://schemas.openxmlformats.org/wordprocessingml/2006/main}val")
            styles.append((text, font, size))
    return styles

styles1 = get_styles(file1)
styles2 = get_styles(file2)

# --- Compare ---
print("Comparing font type/size differences...\n")
for i, (s1, s2) in enumerate(zip(styles1, styles2), start=1):
    text1, font1, size1 = s1
    text2, font2, size2 = s2
    if text1 != text2:
        print(f"Line {i}: Different text -> '{text1}' vs '{text2}'")
    if font1 != font2:
        print(f"Line {i}: Different font -> {font1} vs {font2}")
    if size1 != size2:
        print(f"Line {i}: Different size -> {size1} vs {size2}")

# Handle length mismatch
if len(styles1) != len(styles2):
    print(f"Warning: file1 has {len(styles1)} text runs, file2 has {len(styles2)}")
# Out:
# Comparing font type/size differences...
#
# Line 5: Different font -> Montserrat vs None
# Line 6: Different font -> Montserrat vs Arial
# Line 7: Different font -> Montserrat vs Arial
# Line 8: Different font -> Montserrat vs Arial
# Line 9: Different font -> Montserrat vs Arial
# Line 10: Different font -> Montserrat vs Arial
# Line 11: Different font -> Montserrat vs Arial
# Line 12: Different font -> Montserrat vs Arial
# Line 13: Different font -> Montserrat vs Arial
# Line 14: Different font -> Montserrat vs Arial
# Line 15: Different font -> Montserrat vs Arial
# Line 16: Different font -> Montserrat vs Arial
# Line 17: Different font -> Montserrat vs Arial
# Line 18: Different font -> Montserrat vs Arial
# Line 19: Different font -> Montserrat vs Arial
# Line 20: Different font -> Montserrat vs Arial
# Line 21: Different font -> Montserrat vs Arial
# Line 22: Different font -> Montserrat vs Arial
# Line 23: Different font -> Montserrat vs Arial
# Line 24: Different font -> Montserrat vs Arial
# Line 25: Different font -> Montserrat vs Arial
# Line 26: Different font -> Montserrat vs Arial
# Line 27: Different font -> Montserrat vs Arial
# Line 28: Different font -> Montserrat vs Arial
# Line 29: Different font -> Montserrat vs Arial
# Line 30: Different font -> Montserrat vs Arial
# Line 31: Different font -> Montserrat vs Arial
# Line 32: Different font -> Montserrat vs Arial
# Line 33: Different font -> Montserrat vs Arial
# Line 34: Different font -> Montserrat vs Arial
# Line 35: Different font -> Montserrat vs Arial
# Line 36: Different font -> Montserrat vs Arial
# Line 37: Different font -> Montserrat vs Arial
# Line 38: Different font -> Montserrat vs Arial
# Line 39: Different font -> Montserrat vs Arial
# Line 40: Different font -> Montserrat vs Arial
# Line 41: Different font -> Montserrat vs Arial
# Line 42: Different font -> Montserrat vs Arial
# Line 43: Different font -> Montserrat vs Arial
# Line 44: Different font -> Montserrat vs Arial
# Line 45: Different font -> Montserrat vs Arial
# Line 46: Different font -> Montserrat vs Arial
# Line 47: Different font -> Montserrat vs Arial
# Line 48: Different font -> Montserrat vs Arial
# Line 49: Different font -> Montserrat vs Arial
# Line 50: Different font -> Montserrat vs Arial
# Line 51: Different font -> Montserrat vs Arial
# Line 52: Different font -> Montserrat vs Arial
# Line 53: Different font -> Montserrat vs Arial
# Line 54: Different font -> Montserrat vs Arial
# Line 55: Different font -> Montserrat vs Arial
# Line 56: Different font -> Montserrat vs Arial
# Line 57: Different font -> Montserrat vs Arial
# Line 58: Different font -> Montserrat vs Arial
# Line 59: Different font -> Montserrat vs Arial
# Line 60: Different font -> Montserrat vs Arial
# Line 61: Different font -> Montserrat vs Arial
# Line 62: Different font -> Montserrat vs Arial
# Line 63: Different font -> Montserrat vs Arial
# Line 64: Different font -> Montserrat vs Arial
# Line 65: Different font -> Montserrat vs Arial
# Line 66: Different font -> Montserrat vs Arial
# Line 67: Different font -> Montserrat vs Arial
# Line 68: Different font -> Montserrat vs Arial
# Line 69: Different font -> Montserrat vs Arial
# Line 70: Different font -> Montserrat vs Arial
# Line 71: Different font -> Montserrat vs Arial
# Line 72: Different font -> Montserrat vs Arial
# Line 73: Different font -> Montserrat vs Arial
# Line 74: Different font -> Montserrat vs Arial
# Line 75: Different font -> Montserrat vs Arial
# Line 76: Different font -> Montserrat vs Arial
# Line 77: Different font -> Montserrat vs Arial
# Line 78: Different font -> Montserrat vs Arial
# Line 79: Different font -> Montserrat vs Arial
# Line 80: Different font -> Montserrat vs Arial
# Line 81: Different font -> Montserrat vs Arial
# Line 82: Different font -> Montserrat vs Arial
# Line 83: Different font -> Montserrat vs Arial
# Line 84: Different font -> Montserrat vs Arial
# Line 85: Different font -> Montserrat vs Arial
# Line 86: Different font -> Montserrat vs Arial
# Line 87: Different font -> Montserrat vs Arial
# Line 88: Different font -> Montserrat vs Arial
# Line 89: Different font -> Montserrat vs Arial
# Line 90: Different font -> Montserrat vs Arial
# Line 91: Different font -> Montserrat vs Arial
# Line 92: Different font -> Montserrat vs Arial
# Line 93: Different font -> Montserrat vs Arial
# Line 94: Different font -> Montserrat vs Arial
# Line 95: Different font -> Montserrat vs Arial
# Line 96: Different font -> Montserrat vs Arial
# Line 97: Different font -> Montserrat vs Arial
# Line 98: Different font -> Montserrat vs Arial
# Line 99: Different font -> Montserrat vs Arial
# Line 100: Different font -> Montserrat vs Arial
# Line 101: Different font -> Montserrat vs Arial
# Line 102: Different font -> Montserrat vs Arial
# Line 103: Different font -> Montserrat vs Arial
# Line 104: Different font -> Montserrat vs Arial
# Line 105: Different font -> Montserrat vs Arial
# Line 106: Different font -> Montserrat vs Arial
# Line 107: Different font -> Montserrat vs Arial
# Line 108: Different font -> Montserrat vs Arial
# Line 109: Different font -> Montserrat vs Arial
# Line 110: Different font -> Montserrat vs Arial
# Line 111: Different font -> Montserrat vs Arial
# Line 112: Different font -> Montserrat vs Arial
# Line 113: Different font -> Montserrat vs Arial
# Line 114: Different font -> Montserrat vs Arial
# Line 115: Different font -> Montserrat vs Arial
# Line 116: Different font -> Montserrat vs Arial
# Line 117: Different font -> Montserrat vs Arial
# Line 118: Different font -> Montserrat vs Arial
# Line 119: Different font -> Montserrat vs Arial
# Line 120: Different font -> Montserrat vs Arial
# Line 121: Different font -> Montserrat vs Arial
# Line 122: Different font -> Montserrat vs Arial
# Line 123: Different font -> Montserrat vs Arial
# Line 124: Different font -> Montserrat vs Arial
# Line 125: Different font -> Montserrat vs Arial
# Line 126: Different font -> Montserrat vs Arial
# Line 127: Different font -> Montserrat vs Arial
# Line 128: Different font -> Montserrat vs Arial
# Line 129: Different font -> Montserrat vs Arial
# Line 130: Different font -> Montserrat vs Arial
# Line 131: Different font -> Montserrat vs Arial
# Line 132: Different font -> Montserrat vs Arial
# Line 133: Different font -> Montserrat vs Arial
# Line 134: Different font -> Montserrat vs Arial
# Line 135: Different font -> Montserrat vs Arial
# Line 136: Different font -> Montserrat vs Arial
# Line 137: Different font -> Montserrat vs Arial
# Line 138: Different font -> Montserrat vs Arial
# Line 139: Different font -> Montserrat vs Arial
# Line 140: Different font -> Montserrat vs Arial
# Line 141: Different font -> Montserrat vs Arial
# Line 142: Different font -> Montserrat vs Arial
# Line 143: Different font -> Montserrat vs Arial
# Line 144: Different font -> Montserrat vs Arial
# Line 145: Different font -> Montserrat vs Arial
# Line 146: Different font -> Montserrat vs Arial
# Line 147: Different font -> Montserrat vs Arial
# Line 148: Different font -> Montserrat vs Arial
# Line 149: Different font -> Montserrat vs Arial
# Line 150: Different font -> Montserrat vs Arial
# Line 151: Different font -> Montserrat vs Arial
# Line 152: Different font -> Montserrat vs Arial
# Line 153: Different font -> Montserrat vs Arial
# Line 154: Different font -> Montserrat vs Arial
# Line 155: Different font -> Montserrat vs Arial
# Line 156: Different font -> Montserrat vs Arial
# Line 157: Different font -> Montserrat vs Arial
# Line 158: Different font -> Montserrat vs Arial
# Line 159: Different font -> Montserrat vs Arial
# Line 160: Different font -> Montserrat vs Arial
# Line 161: Different font -> Montserrat vs Arial
# Line 162: Different font -> Montserrat vs Arial
# Line 163: Different font -> Montserrat vs Arial
# Line 164: Different font -> Montserrat vs Arial
# Line 165: Different font -> Montserrat vs Arial
# Line 166: Different font -> Montserrat vs Arial
# Line 167: Different font -> Montserrat vs Arial
# Line 168: Different font -> Montserrat vs Arial
# Line 169: Different font -> Montserrat vs Arial
# Line 170: Different font -> Montserrat vs Arial
# Line 171: Different font -> Montserrat vs Arial
# Line 172: Different font -> Montserrat vs Arial
# Line 173: Different font -> Montserrat vs Arial
# Line 174: Different font -> Montserrat vs Arial
# Line 175: Different font -> Montserrat vs Arial
# Line 176: Different font -> Montserrat vs Arial
# Line 177: Different font -> Montserrat vs Arial
# Line 178: Different font -> Montserrat vs Arial
# Line 179: Different font -> Montserrat vs Arial
# Line 180: Different font -> Montserrat vs Arial
# Line 181: Different font -> Montserrat vs Arial
# Line 182: Different font -> Montserrat vs Arial
# Line 183: Different font -> Montserrat vs Arial
# Line 184: Different font -> Montserrat vs Arial
# Line 185: Different font -> Montserrat vs Arial
# Line 186: Different font -> Montserrat vs Arial
# Line 187: Different font -> Montserrat vs Arial
# Line 188: Different font -> Montserrat vs Arial
# Line 189: Different font -> Montserrat vs Arial
# Line 190: Different font -> Montserrat vs Arial
# Line 191: Different font -> Montserrat vs Arial
# Line 192: Different font -> Montserrat vs Arial
# Line 193: Different font -> Montserrat vs Arial
# Line 194: Different font -> Montserrat vs Arial
# Line 195: Different font -> Montserrat vs Arial
# Line 196: Different font -> Montserrat vs Arial
# Line 197: Different font -> Montserrat vs Arial
# Line 198: Different font -> Montserrat vs Arial
# Line 199: Different font -> Montserrat vs Arial
# Line 200: Different font -> Montserrat vs Arial
# Line 201: Different font -> Montserrat vs Arial
# Line 202: Different font -> Montserrat vs Arial
# Line 203: Different font -> Montserrat vs Arial
# Line 204: Different font -> Montserrat vs Arial
# Line 205: Different font -> Montserrat vs Arial
# Line 206: Different font -> Montserrat vs Arial
# Line 207: Different font -> Montserrat vs Arial
# Line 208: Different font -> Montserrat vs Arial
# Line 209: Different font -> Montserrat vs Arial
# Line 210: Different font -> Montserrat vs Arial
# Line 211: Different font -> Montserrat vs Arial
# Line 212: Different font -> Montserrat vs Arial
# Line 213: Different font -> Montserrat vs Arial
# Line 214: Different font -> Montserrat vs Arial
# Line 215: Different font -> Montserrat vs Arial
# Line 216: Different font -> Montserrat vs Arial
# Line 217: Different font -> Montserrat vs Arial
# Line 218: Different font -> Montserrat vs Arial
# Line 219: Different font -> Montserrat vs Arial
# Line 220: Different font -> Montserrat vs Arial
# Line 221: Different font -> Montserrat vs Arial
# Line 222: Different font -> Montserrat vs Arial
# Line 223: Different font -> Montserrat vs Arial
# Line 224: Different font -> Montserrat vs Arial
# Line 225: Different font -> Montserrat vs Arial
# Line 226: Different font -> Montserrat vs Arial
# Line 227: Different font -> Montserrat vs Arial
# Line 228: Different font -> Montserrat vs Arial
# Line 229: Different font -> Montserrat vs Arial
# Line 230: Different font -> Montserrat vs Arial
# Line 231: Different font -> Montserrat vs Arial
# Line 232: Different font -> Montserrat vs Arial
# Line 233: Different font -> Montserrat vs Arial
# Line 234: Different font -> Montserrat vs Arial
# Line 235: Different font -> Montserrat vs Arial
# Line 236: Different font -> Montserrat vs Arial
# Line 237: Different font -> Montserrat vs Arial
# Line 238: Different font -> Montserrat vs Arial
# Line 239: Different font -> Montserrat vs Arial
# Line 240: Different font -> Montserrat vs Arial
# Line 241: Different font -> Montserrat vs Arial
# Line 242: Different font -> Montserrat vs Arial
# Line 243: Different font -> Montserrat vs Arial
# Line 244: Different font -> Montserrat vs Arial
# Line 245: Different font -> Montserrat vs Arial
# Line 246: Different font -> Montserrat vs Arial
# Line 247: Different font -> Montserrat vs Arial
# Line 248: Different font -> Montserrat vs Arial
# Line 249: Different font -> Montserrat vs Arial
# Line 250: Different font -> Montserrat vs Arial
# Line 251: Different font -> Montserrat vs Arial
# Line 252: Different font -> Montserrat vs Arial
# Line 253: Different font -> Montserrat vs Arial
# Line 254: Different font -> Montserrat vs Arial
# Line 255: Different font -> Montserrat vs Arial
# Line 256: Different font -> Montserrat vs Arial
# Line 257: Different font -> Montserrat vs Arial
# Line 258: Different font -> Montserrat vs Arial
# Line 259: Different font -> Montserrat vs Arial
# Line 260: Different font -> Montserrat vs Arial
# Line 261: Different font -> Montserrat vs Arial
# Line 262: Different font -> Montserrat vs Arial
# Line 263: Different font -> Montserrat vs Arial
# Line 264: Different font -> Montserrat vs Arial
# Line 265: Different font -> Montserrat vs Arial
# Line 266: Different font -> Montserrat vs Arial
# Line 267: Different font -> Montserrat vs Arial
# Line 268: Different font -> Montserrat vs Arial
# Line 269: Different font -> Montserrat vs Arial
# Line 270: Different font -> Montserrat vs Arial
# Line 271: Different font -> Montserrat vs Arial
# Line 272: Different font -> Montserrat vs Arial
# Line 273: Different font -> Montserrat vs Arial
# Line 274: Different font -> Montserrat vs Arial
# Line 275: Different font -> Montserrat vs Arial
# Line 276: Different font -> Montserrat vs Arial
# Line 277: Different font -> Montserrat vs Arial
# Line 278: Different font -> Montserrat vs Arial
# Line 279: Different font -> Montserrat vs Arial
# Line 280: Different font -> Montserrat vs Arial
# Line 281: Different font -> Montserrat vs Arial
# Line 282: Different font -> Montserrat vs Arial
# Line 283: Different font -> Montserrat vs Arial
# Line 284: Different font -> Montserrat vs Arial
# Line 285: Different font -> Montserrat vs Arial
# Line 286: Different font -> Montserrat vs Arial
# Line 287: Different font -> Montserrat vs Arial
# Line 288: Different font -> Montserrat vs Arial
# Line 289: Different font -> Montserrat vs Arial
# Line 290: Different font -> Montserrat vs Arial
# Line 291: Different font -> Montserrat vs Arial
# Line 292: Different font -> Montserrat vs Arial
# Line 293: Different font -> Montserrat vs Arial
# Line 294: Different font -> Montserrat vs Arial
# Line 295: Different font -> Montserrat vs Arial
# Line 296: Different font -> Montserrat vs Arial
# Line 297: Different font -> Montserrat vs Arial
# Line 298: Different font -> Montserrat vs Arial
# Line 299: Different font -> Montserrat vs Arial
# Line 300: Different font -> Montserrat vs Arial
# Line 301: Different font -> Montserrat vs Arial
# Line 302: Different font -> Montserrat vs Arial
# Line 303: Different font -> Montserrat vs Arial
# Line 304: Different font -> Montserrat vs Arial
# Line 305: Different font -> Montserrat vs Arial
# Line 306: Different font -> Montserrat vs Arial
# Line 307: Different font -> Montserrat vs Arial
# Line 308: Different font -> Montserrat vs Arial
# Line 309: Different font -> Montserrat vs Arial
# Line 310: Different font -> Montserrat vs Arial
# Line 311: Different font -> Montserrat vs Arial
# Line 312: Different font -> Montserrat vs Arial
# Line 313: Different font -> Montserrat vs Arial
# Line 314: Different font -> Montserrat vs Arial
# Line 315: Different font -> Montserrat vs Arial
# Line 316: Different font -> Montserrat vs Arial
# Line 317: Different font -> Montserrat vs Arial
# Line 318: Different font -> Montserrat vs Arial
# Line 319: Different font -> Montserrat vs Arial
# Line 320: Different font -> Montserrat vs Arial
# Line 321: Different font -> Montserrat vs Arial
# Line 322: Different font -> Montserrat vs Arial
# Line 323: Different font -> Montserrat vs Arial
# Line 324: Different font -> Montserrat vs Arial
# Line 325: Different font -> Montserrat vs Arial
# Line 326: Different font -> Montserrat vs Arial
# Line 327: Different font -> Montserrat vs Arial
# Line 328: Different font -> Montserrat vs Arial
# Line 329: Different font -> Montserrat vs Arial
# Line 330: Different font -> Montserrat vs Arial
# Line 331: Different font -> Montserrat vs Arial
# Line 332: Different font -> Montserrat vs Arial
# Line 333: Different font -> Montserrat vs Arial
# Line 334: Different font -> Montserrat vs Arial
# Line 335: Different font -> Montserrat vs Arial
# Line 336: Different font -> Montserrat vs Arial
# Line 337: Different font -> Montserrat vs Arial
# Line 338: Different font -> Montserrat vs Arial
# Line 339: Different font -> Montserrat vs Arial
# Line 340: Different font -> Montserrat vs Arial
# Line 341: Different font -> Montserrat vs Arial
# Line 342: Different font -> Montserrat vs Arial
# Line 343: Different font -> Montserrat vs Arial
# Line 344: Different font -> Montserrat vs Arial
# Line 345: Different font -> Montserrat vs Arial
# Line 346: Different font -> Montserrat vs Arial
# Line 347: Different font -> Montserrat vs Arial
# Line 348: Different font -> Montserrat vs Arial
# Line 349: Different font -> Montserrat vs Arial
# Line 350: Different font -> Montserrat vs Arial
# Line 351: Different font -> Montserrat vs Arial
# Line 352: Different font -> Montserrat vs Arial
# Line 353: Different font -> Montserrat vs Arial
# Line 354: Different font -> Montserrat vs Arial
# Line 355: Different font -> Montserrat vs Arial
# Line 356: Different font -> Montserrat vs Arial
# Line 357: Different font -> Montserrat vs Arial
# Line 358: Different font -> Montserrat vs Arial
# Line 359: Different font -> Montserrat vs Arial
# Line 360: Different font -> Montserrat vs Arial
# Line 361: Different font -> Montserrat vs Arial
# Line 362: Different font -> Montserrat vs Arial
# Line 363: Different font -> Montserrat vs Arial
# Line 364: Different font -> Montserrat vs Arial
# Line 365: Different font -> Montserrat vs Arial
# Line 366: Different font -> Montserrat vs Arial
# Line 367: Different font -> Montserrat vs Arial
# Line 368: Different font -> Montserrat vs Arial
# Line 369: Different font -> Montserrat vs Arial
# Line 370: Different font -> Montserrat vs Arial
# Line 371: Different font -> Montserrat vs Arial
# Line 372: Different font -> Montserrat vs Arial
# Line 373: Different font -> Montserrat vs Arial
# Line 374: Different font -> Montserrat vs Arial
# Line 375: Different font -> Montserrat vs Arial
# Line 376: Different text -> 'Categorie ' vs 'Categorie'
# Line 376: Different font -> Montserrat vs Arial
# Line 377: Different font -> Montserrat vs Arial
# Line 378: Different font -> Montserrat vs Arial
# Line 379: Different font -> Montserrat vs Arial
# Line 380: Different font -> Montserrat vs Arial
# Line 381: Different font -> Montserrat vs Arial
# Line 382: Different font -> Montserrat vs Arial
# Line 383: Different font -> Montserrat vs Arial
# Line 384: Different font -> Montserrat vs Arial
# Line 385: Different font -> Montserrat vs Arial
# Line 386: Different font -> Montserrat vs Arial
# Line 387: Different font -> Montserrat vs Arial
# Line 388: Different font -> Montserrat vs Arial
# Line 389: Different font -> Montserrat vs Arial
# Line 390: Different font -> Montserrat vs Arial
# Line 391: Different font -> Montserrat vs Arial
# Line 392: Different font -> Montserrat vs Arial
# Line 393: Different font -> Montserrat vs Arial
# Line 394: Different font -> Montserrat vs Arial
# Line 395: Different font -> Montserrat vs Arial
# Line 396: Different font -> Montserrat vs Arial
# Line 397: Different font -> Montserrat vs Arial
# Line 398: Different font -> Montserrat vs Arial
# Line 399: Different font -> Montserrat vs Arial
# Line 400: Different font -> Montserrat vs Arial
# Line 401: Different font -> Montserrat vs Arial
# Line 402: Different font -> Montserrat vs Arial
# Line 403: Different font -> Montserrat vs Arial
# Line 404: Different font -> Montserrat vs Arial
# Line 405: Different font -> Montserrat vs Arial
# Line 406: Different font -> Montserrat vs Arial
# Line 407: Different font -> Montserrat vs Arial
# Line 408: Different font -> Montserrat vs Arial
# Line 409: Different font -> Montserrat vs Arial
# Line 410: Different font -> Montserrat vs Arial
# Line 411: Different font -> Montserrat vs Arial
# Line 412: Different font -> Montserrat vs Arial
# Line 413: Different font -> Montserrat vs Arial
# Line 414: Different font -> Montserrat vs Arial
# Line 415: Different font -> Montserrat vs Arial
# Line 416: Different font -> Montserrat vs Arial
# Line 417: Different font -> Montserrat vs Arial
# Line 418: Different font -> Montserrat vs Arial
# Line 419: Different font -> Montserrat vs Arial
# Line 420: Different font -> Montserrat vs Arial
# Line 421: Different font -> Montserrat vs Arial
# Line 422: Different font -> Montserrat vs Arial
# Line 423: Different font -> Montserrat vs Arial
# Line 424: Different font -> Montserrat vs Arial
# Line 425: Different font -> Montserrat vs Arial
# Line 426: Different font -> Montserrat vs Arial
# Line 427: Different font -> Montserrat vs Arial
# Line 428: Different font -> Montserrat vs Arial
# Line 429: Different font -> Montserrat vs Arial
# Line 430: Different font -> Montserrat vs Arial
# Line 431: Different font -> Montserrat vs Arial
# Line 432: Different font -> Montserrat vs Arial
# Line 433: Different font -> Montserrat vs Arial
# Line 434: Different font -> Montserrat vs Arial
# Line 435: Different font -> Montserrat vs Arial
# Line 436: Different font -> Montserrat vs Arial
# Line 437: Different font -> Montserrat vs Arial
# Line 438: Different font -> Montserrat vs Arial
# Line 439: Different font -> Montserrat vs Arial

# %%
import zipfile
import xml.etree.ElementTree as ET
from docx import Document
from docx.enum.text import WD_COLOR_INDEX

# --- CONFIG ---
file1 = "Zoekwoordenonderzoek.docx"
file2 = "Zoekwoordenonderzoek2.docx"
output_file = "Zoekwoordenonderzoek2_highlighted.docx"

# --- Extract text + font info ---
def get_styles(docx_file):
    styles = []
    with zipfile.ZipFile(docx_file) as docx:
        xml_content = docx.read("word/document.xml")
        tree = ET.fromstring(xml_content)
        ns = {"w": "http://schemas.openxmlformats.org/wordprocessingml/2006/main"}

        for r in tree.findall(".//w:r", ns):
            text = "".join([t.text for t in r.findall("w:t", ns) if t.text])
            if not text.strip():
                continue
            rpr = r.find("w:rPr", ns)
            font, size = None, None
            if rpr is not None:
                rfonts = rpr.find("w:rFonts", ns)
                if rfonts is not None:
                    font = rfonts.attrib.get("{http://schemas.openxmlformats.org/wordprocessingml/2006/main}ascii")
                rsize = rpr.find("w:sz", ns)
                if rsize is not None:
                    size = rsize.attrib.get("{http://schemas.openxmlformats.org/wordprocessingml/2006/main}val")
            styles.append((text, font, size))
    return styles

# --- Extract all runs, including inside tables ---
def get_all_runs(doc):
    runs = []

    def collect_runs_from_paragraphs(paragraphs):
        for para in paragraphs:
            for run in para.runs:
                if run.text.strip():
                    runs.append(run)

    def collect_runs_from_tables(tables):
        for table in tables:
            for row in table.rows:
                for cell in row.cells:
                    collect_runs_from_paragraphs(cell.paragraphs)
                    collect_runs_from_tables(cell.tables)  # handle nested tables

    collect_runs_from_paragraphs(doc.paragraphs)
    collect_runs_from_tables(doc.tables)
    return runs

# --- Compare and highlight differences ---
def highlight_differences(file1, file2, output_file):
    styles1 = get_styles(file1)
    styles2 = get_styles(file2)

    doc2 = Document(file2)
    runs2 = get_all_runs(doc2)

    print(f"Comparing {len(styles1)} vs {len(styles2)} text runs...")

    for i, (s1, s2) in enumerate(zip(styles1, styles2)):
        if i >= len(runs2):
            break
        text1, font1, size1 = s1
        text2, font2, size2 = s2
        run = runs2[i]
        if text1 != text2 or font1 != font2 or size1 != size2:
            run.font.highlight_color = WD_COLOR_INDEX.YELLOW

    if len(styles1) != len(styles2):
        print(f"Warning: file1 has {len(styles1)} runs, file2 has {len(styles2)}")

    doc2.save(output_file)
    print(f"Saved highlighted file: {output_file}")

# --- Run ---
highlight_differences(file1, file2, output_file)
# Out:
# Comparing 439 vs 439 text runs...
# Saved highlighted file: Zoekwoordenonderzoek2_highlighted.docx

# %%
import json
from docx import Document

# --- CONFIG ---
target_font = "Montserrat"
file_path = "Zoekwoordenonderzoek2.docx"
output_json = "font_mismatches.json"

# --- Extract all runs (including inside tables) ---
def get_all_runs(doc):
    runs = []
    line_counter = 0

    def collect_runs_from_paragraphs(paragraphs):
        nonlocal line_counter
        for para in paragraphs:
            line_counter += 1
            for run in para.runs:
                if run.text.strip():
                    runs.append((line_counter, run))

    def collect_runs_from_tables(tables):
        for table in tables:
            for row in table.rows:
                for cell in row.cells:
                    collect_runs_from_paragraphs(cell.paragraphs)
                    collect_runs_from_tables(cell.tables)

    collect_runs_from_paragraphs(doc.paragraphs)
    collect_runs_from_tables(doc.tables)
    return runs

# --- Extract font name from run ---
def get_font_from_run(run):
    if run.font.name:
        return run.font.name

    # Fallback: get font from XML
    r = run._element
    rPr = r.find(".//w:rPr", namespaces={"w": "http://schemas.openxmlformats.org/wordprocessingml/2006/main"})
    if rPr is not None:
        rFonts = rPr.find("w:rFonts", namespaces={"w": "http://schemas.openxmlformats.org/wordprocessingml/2006/main"})
        if rFonts is not None:
            return rFonts.attrib.get("{http://schemas.openxmlformats.org/wordprocessingml/2006/main}ascii")
    return None

# --- Check font consistency ---
def check_font_consistency(docx_file, target_font):
    doc = Document(docx_file)
    runs = get_all_runs(doc)
    mismatches = []

    for line_num, run in runs:
        font_name = get_font_from_run(run)

        # Skip runs with no detected font
        if not font_name:
            continue

        # Add only mismatched fonts
        if font_name != target_font:
            mismatches.append({
                "line": line_num,
                "text": run.text.strip(),
                "reason": f"Font is '{font_name}' instead of '{target_font}'"
            })

    print(f"Checked {len(runs)} text runs.")
    print(f"Found {len(mismatches)} font mismatches (not '{target_font}').")

    return mismatches

# --- Run check and export to JSON ---
mismatches = check_font_consistency(file_path, target_font)

with open(output_json, "w", encoding="utf-8") as f:
    json.dump(mismatches, f, ensure_ascii=False, indent=4)

print(f"Results saved to {output_json}")
# Out:
# Checked 439 text runs.
# Found 434 font mismatches (not 'Montserrat').
# Results saved to font_mismatches.json

# %%
import json
from docx import Document

def get_all_runs(doc):
    runs = []
    para_counter = 0
    current_section = None  # no default section yet

    def collect_runs_from_paragraphs(paragraphs):
        nonlocal para_counter, current_section
        for para in paragraphs:
            para_counter += 1
            style_name = para.style.name if para.style else ""
            
            # If paragraph is a heading, update section
            if style_name.startswith("Heading"):
                current_section = para.text.strip()
            
            # If no section yet and paragraph has text, treat it as first section
            elif current_section is None and para.text.strip():
                current_section = para.text.strip()
            
            # Add each non-empty run
            for run in para.runs:
                if run.text.strip():
                    runs.append({
                        "paragraph": para_counter,
                        "section": current_section,
                        "run": run
                    })

    def collect_runs_from_tables(tables):
        for table in tables:
            for row in table.rows:
                for cell in row.cells:
                    collect_runs_from_paragraphs(cell.paragraphs)
                    collect_runs_from_tables(cell.tables)

    collect_runs_from_paragraphs(doc.paragraphs)
    collect_runs_from_tables(doc.tables)
    return runs



# --- Extract font name from run ---
def get_font_from_run(run):
    if run.font.name:
        return run.font.name

    # Fallback: get font from XML
    r = run._element
    rPr = r.find(".//w:rPr", namespaces={"w": "http://schemas.openxmlformats.org/wordprocessingml/2006/main"})
    if rPr is not None:
        rFonts = rPr.find("w:rFonts", namespaces={"w": "http://schemas.openxmlformats.org/wordprocessingml/2006/main"})
        if rFonts is not None:
            return rFonts.attrib.get("{http://schemas.openxmlformats.org/wordprocessingml/2006/main}ascii")
    return None

# --- Check font consistency ---
def check_font_consistency(docx_file, target_font):
    doc = Document(docx_file)
    run_entries = get_all_runs(doc)
    mismatches = []

    for entry in run_entries:
        font_name = get_font_from_run(entry["run"])
        if not font_name:
            continue
        if font_name != target_font:
            mismatches.append({
                "paragraph": entry["paragraph"],
                "section": entry["section"],
                "text": entry["run"].text.strip(),
                "reason": f"Font is '{font_name}' instead of '{target_font}'"
            })

    print(f"Checked {len(run_entries)} text runs.")
    print(f"Found {len(mismatches)} font mismatches (not '{target_font}').")

    return mismatches

# --- Run check and export to JSON ---
mismatches = check_font_consistency(file_path, target_font)

with open(output_json, "w", encoding="utf-8") as f:
    json.dump(mismatches, f, ensure_ascii=False, indent=4)

print(f"Results saved to {output_json}")
# Out:
# Checked 439 text runs.
# Found 434 font mismatches (not 'Montserrat').
# Results saved to font_mismatches.json

# %%
import json
from reportlab.lib.pagesizes import A4
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Table, TableStyle, Paragraph, Spacer, Image
from reportlab.lib.styles import getSampleStyleSheet

# ---------- 1. Load JSON mismatches (only first mismatch per section) ----------
def load_mismatches_from_json(json_file):
    with open(json_file, "r", encoding="utf-8") as f:
        mismatches = json.load(f)

    seen_sections = set()
    converted = []
    for m in mismatches:
        section = m.get("section", "Geen sectie")

        # Skip if we've already added a mismatch for this section
        if section in seen_sections:
            continue
        seen_sections.add(section)

        # Parse reason to extract found font and expected font
        reason = m.get("reason", "")
        if "instead of" in reason:
            parts = reason.replace("Font is '", "").replace("'", "").split(" instead of ")
            gevonden = parts[0].strip()
            verwacht = parts[1].strip() if len(parts) > 1 else "Montserrat"
        else:
            gevonden = "Onbekend"
            verwacht = "Montserrat"

        converted.append({
            "element": f"Paragraaf {m['paragraph']}",
            "type": "lettertype",
            "verwacht": verwacht,
            "gevonden": gevonden,
            "pagina": 1,  # Could later estimate page
            "ernst": "laag",
            "text": m["text"],
            "section": section
        })

    return converted


# ---------- 2. Console rapport ----------
def generate_console_report(data):
    print("Rapport van afwijkingen:")
    kleurcodes = {"laag": "\033[92m", "gemiddeld": "\033[93m", "hoog": "\033[91m"}
    reset = "\033[0m"
    print(f"{'Element':<15}{'Type':<12}{'Verwacht':<12}{'Gevonden':<12}{'Pagina':<6}{'Ernst'}")
    for item in data:
        kleur = kleurcodes[item['ernst']]
        print(f"{kleur}{item['element']:<15}{item['type']:<12}{item['verwacht']:<12}{item['gevonden']:<12}{item['pagina']:<6}{item['ernst']}{reset}")

# ---------- 3. PDF rapport ----------
def generate_pdf_report(data, pdf_file="rapport_fontcheck.pdf", logo_path=None):
    doc = SimpleDocTemplate(pdf_file, pagesize=A4)
    elements = []
    styles = getSampleStyleSheet()

    # Logo toevoegen (optioneel)
    if logo_path:
        try:
            img = Image(logo_path, width=100, height=50)
            img.hAlign = 'RIGHT'
            elements.append(img)
            elements.append(Spacer(1, 12))
        except Exception as e:
            print(f"Kon logo niet laden: {e}")

    # Titel
    title = Paragraph("Laméco Documentstijl Controle Rapport", styles['Title'])
    elements.append(title)
    elements.append(Spacer(1, 12))

    # Tabeldata
    table_data = [["Element", "Type", "Verwacht", "Gevonden", "Pagina", "Ernst"]]
    for item in data:
        table_data.append([item['element'], item['type'], item['verwacht'], item['gevonden'], str(item['pagina']), item['ernst']])

    table = Table(table_data, repeatRows=1)
    style = TableStyle([
        ('BACKGROUND', (0,0), (-1,0), colors.lightgrey),
        ('GRID', (0,0), (-1,-1), 1, colors.black),
        ('ALIGN', (4,1), (4,-1), 'CENTER')
    ])

    # Kleurcodering per ernst
    for i, item in enumerate(data, start=1):
        if item['ernst'] == 'hoog':
            style.add('BACKGROUND', (0,i), (-1,i), colors.salmon)
        elif item['ernst'] == 'gemiddeld':
            style.add('BACKGROUND', (0,i), (-1,i), colors.yellow)
        else:
            style.add('BACKGROUND', (0,i), (-1,i), colors.lightgreen)

    table.setStyle(style)
    elements.append(table)
    elements.append(Spacer(1, 12))

    # Legenda
    legend_text = "Legenda: Hoog = rood, Gemiddeld = geel, Laag = groen"
    elements.append(Paragraph(legend_text, styles['Normal']))

    doc.build(elements)
    print(f"\nPDF-rapport gegenereerd: {pdf_file}")

# ---------- 4. Main ----------
if __name__ == "__main__":
    json_file = "font_mismatches.json"  # Output from your font check script
    data = load_mismatches_from_json(json_file)

    generate_console_report(data)
    generate_pdf_report(data, pdf_file="rapport_fontcheck.pdf", logo_path="laméco_logo.png")
# Out:
# Rapport van afwijkingen:
# Element        Type        Verwacht    Gevonden    PaginaErnst
# Paragraaf 13   lettertype  Montserrat  Arial       1     laag
#
# PDF-rapport gegenereerd: rapport_fontcheck.pdf
